# %% [markdown]
# # Introdução ao R
#
# O que veremos nessa aula:
#
# * Gerenciamento de pacotes
# * Operadores aritméticos
# * Tipos de dados em R
# * Variáveis
# * Identificadores
# * Comando de atribuição
# * Impressão e leitura de variáveis
# * Operadores relacionais
# * Operadores lógicos
# * Gerenciando objetos na memória
#
# Referência: [Manuais](https://cran.r-project.org/manuals.html) criados pelo grupo de desenvolvedores do R.

# %% [markdown]
# ## Gerenciamento de pacotes

# %%
# Visualizando os pacotes instalados
installed.packages()
# Out:
#              Package
# askpass      askpass
# assertthat   assertthat
# backports    backports
# base         base
# base64enc    base64enc
# BH           BH
# boot         boot
# broom        broom
# callr        callr
# caret        caret
# cellranger   cellranger
# class        class
# cli          cli
# clipr        clipr
# cluster      cluster
# codetools    codetools
# colorspace   colorspace
# compiler     compiler
# crayon       crayon
# curl         curl
# data.table   data.table
# datasets     datasets
# DBI          DBI
# dbplyr       dbplyr
# dichromat    dichromat
# digest       digest
# dplyr        dplyr
# ellipsis     ellipsis
# evaluate     evaluate
# fansi        fansi
# ...          ...
# splines      splines
# SQUAREM      SQUAREM
# stats        stats
# stats4       stats4
# stringi      stringi
# stringr      stringr
# survival     survival
# sys          sys
# tcltk        tcltk
# tibble       tibble
# tidyr        tidyr
# tidyselect   tidyselect
# tidyverse    tidyverse
# timeDate     timeDate
# tinytex      tinytex
# tools        tools
# translations translations
# TTR          TTR
# utf8         utf8
# utils        utils
# uuid         uuid
# viridisLite  viridisLite
# whisker      whisker
# withr        withr
# xfun         xfun
# xml2         xml2
# xtable       xtable
# xts          xts
# yaml         yaml
# zoo          zoo
#              LibPath
# askpass      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# assertthat   C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# backports    C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# base         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# base64enc    C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# BH           C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# boot         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# broom        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# callr        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# caret        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# cellranger   C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# class        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# cli          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# clipr        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# cluster      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# codetools    C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# colorspace   C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# compiler     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# crayon       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# curl         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# data.table   C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# datasets     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# DBI          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# dbplyr       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# dichromat    C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# digest       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# dplyr        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# ellipsis     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# evaluate     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# fansi        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# ...          ...
# splines      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# SQUAREM      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# stats        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# stats4       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# stringi      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# stringr      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# survival     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# sys          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tcltk        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tibble       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tidyr        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tidyselect   C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tidyverse    C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# timeDate     C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tinytex      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# tools        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# translations C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# TTR          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# utf8         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# utils        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# uuid         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# viridisLite  C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# whisker      C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# withr        C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# xfun         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# xml2         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# xtable       C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# xts          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# yaml         C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
# zoo          C:/Users/rolivei5/.conda/envs/R - Jupiter Notebook/Lib/R/library
#              Version   Priority
# askpass      1.0       NA
# assertthat   0.2.1     NA
# backports    1.1.4     NA
# base         3.6.1     base
# base64enc    0.1-3     NA
# BH           1.69.0-1  NA
# boot         1.3-20    recommended
# broom        0.5.2     NA
# callr        3.2.0     NA
# caret        6.0-83    NA
# cellranger   1.1.0     NA
# class        7.3-15    recommended
# cli          1.1.0     NA
# clipr        0.6.0     NA
# cluster      2.0.8     recommended
# codetools    0.2-16    recommended
# colorspace   1.4-1     NA
# compiler     3.6.1     base
# crayon       1.3.4     NA
# curl         3.3       NA
# data.table   1.12.2    NA
# datasets     3.6.1     base
# DBI          1.0.0     NA
# dbplyr       1.4.0     NA
# dichromat    2.0-0     NA
# digest       0.6.18    NA
# dplyr        0.8.0.1   NA
# ellipsis     0.1.0     NA
# evaluate     0.13      NA
# fansi        0.4.0     NA
# ...          ...       ...
# splines      3.6.1     base
# SQUAREM      2017.10-1 NA
# stats        3.6.1     base
# stats4       3.6.1     base
# stringi      1.4.3     NA
# stringr      1.4.0     NA
# survival     2.44-1.1  recommended
# sys          3.2       NA
# tcltk        3.6.1     base
# tibble       2.1.1     NA
# tidyr        0.8.3     NA
# tidyselect   0.2.5     NA
# tidyverse    1.2.1     NA
# timeDate     3043.102  NA
# tinytex      0.12      NA
# tools        3.6.1     base
# translations 3.6.1     NA
# TTR          0.23-4    NA
# utf8         1.1.4     NA
# utils        3.6.1     base
# uuid         0.1-2     NA
# viridisLite  0.3.0     NA
# whisker      0.3-2     NA
# withr        2.1.2     NA
# xfun         0.6       NA
# xml2         1.2.0     NA
# xtable       1.8-4     NA
# xts          0.11-2    NA
# yaml         2.2.0     NA
# zoo          1.8-5     NA
#              Depends
# askpass      NA
# assertthat   NA
# backports    R (>= 3.0.0)
# base         NA
# base64enc    R (>= 2.9.0)
# BH           NA
# boot         R (>= 3.0.0), graphics, stats
# broom        R (>= 3.1)
# callr        NA
# caret        R (>= 3.5.0), lattice (>= 0.20), ggplot2
# cellranger   R (>= 3.0.0)
# class        R (>= 3.0.0), stats, utils
# cli          R (>= 2.10)
# clipr        NA
# cluster      R (>= 3.3.0)
# codetools    R (>= 2.1)
# colorspace   R (>= 3.0.0), methods
# compiler     NA
# crayon       NA
# curl         R (>= 3.0.0)
# data.table   R (>= 3.1.0)
# datasets     NA
# DBI          R (>= 3.0.0), methods
# dbplyr       R (>= 3.1)
# dichromat    R (>= 2.10), stats
# digest       R (>= 3.1.0)
# dplyr        R (>= 3.1.2)
# ellipsis     R (>= 3.1)
# evaluate     R (>= 3.0.2)
# fansi        R (>= 3.1.0)
# ...          ...
# splines      NA
# SQUAREM      R (>= 3.0)
# stats        NA
# stats4       NA
# stringi      R (>= 2.14)
# stringr      R (>= 3.1)
# survival     R (>= 2.13.0)
# sys          NA
# tcltk        NA
# tibble       R (>= 3.1.0)
# tidyr        R (>= 3.1)
# tidyselect   R (>= 3.1)
# tidyverse    NA
# timeDate     R (>= 2.15.1), graphics, utils, stats, methods
# tinytex      NA
# tools        NA
# translations NA
# TTR          NA
# utf8         R (>= 2.10)
# utils        NA
# uuid         R (>= 2.9.0)
# viridisLite  R (>= 2.10)
# whisker      NA
# withr        R (>= 3.0.2)
# xfun         NA
# xml2         R (>= 3.1.0)
# xtable       R (>= 2.10.0)
# xts          zoo (>= 1.7-12)
# yaml         NA
# zoo          R (>= 3.1.0), stats
#              Imports
# askpass      sys (>= 2.1)
# assertthat   tools
# backports    utils
# base         NA
# base64enc    NA
# BH           NA
# boot         NA
# broom        backports, dplyr, generics (>= 0.0.2), methods, nlme, purrr,\nreshape2, stringr, tibble, tidyr
# callr        processx (>= 3.3.0), R6, utils
# caret        foreach, methods, plyr, ModelMetrics (>= 1.1.0), nlme,\nreshape2, stats, stats4, utils, grDevices, recipes (>= 0.1.4),\nwithr (>= 2.0.0)
# cellranger   rematch, tibble
# class        MASS
# cli          assertthat, crayon (>= 1.3.4), methods, utils
# clipr        utils
# cluster      graphics, grDevices, stats, utils
# codetools    NA
# colorspace   graphics, grDevices, stats
# compiler     NA
# crayon       grDevices, methods, utils
# curl         NA
# data.table   methods
# datasets     NA
# DBI          NA
# dbplyr       assertthat (>= 0.2.0), DBI (>= 1.0.0), dplyr (>= 0.8.0), glue\n(>= 1.2.0), methods, purrr (>= 0.2.5), R6 (>= 2.2.2), rlang (>=\n0.2.0), tibble (>= 1.4.2), tidyselect (>= 0.2.4), utils
# dichromat    NA
# digest       NA
# dplyr        assertthat (>= 0.2.0), glue (>= 1.1.1), magrittr (>= 1.5),\nmethods, pkgconfig (>= 2.0.1), R6 (>= 2.2.2), Rcpp (>= 1.0.0),\nrlang (>= 0.3.0), tibble (>= 2.0.0), tidyselect (>= 0.2.5),\nutils
# ellipsis     NA
# evaluate     methods
# fansi        NA
# ...          ...
# splines      graphics, stats
# SQUAREM      NA
# stats        utils, grDevices, graphics
# stats4       graphics, methods, stats
# stringi      tools, utils, stats
# stringr      glue (>= 1.2.0), magrittr, stringi (>= 1.1.7)
# survival     graphics, Matrix, methods, splines, stats, utils
# sys          NA
# tcltk        utils
# tibble       cli (>= 1.0.1), crayon (>= 1.3.4), fansi (>= 0.4.0), methods,\npillar (>= 1.3.1), pkgconfig (>= 2.0.2), rlang (>= 0.3.1),\nutils
# tidyr        dplyr (>= 0.7.0), glue, magrittr, purrr, Rcpp, rlang, stringi,\ntibble, tidyselect (>= 0.2.5), utils
# tidyselect   glue (>= 1.3.0), purrr, rlang (>= 0.2.2), Rcpp (>= 0.12.0)
# tidyverse    broom (>= 0.4.2), cli (>= 1.0.0), crayon (>= 1.3.4), dplyr (>=\n0.7.4), dbplyr (>= 1.1.0), forcats (>= 0.2.0), ggplot2 (>=\n2.2.1), haven (>= 1.1.0), hms (>= 0.3), httr (>= 1.3.1),\njsonlite (>= 1.5), lubridate (>= 1.7.1), magrittr (>= 1.5),\nmodelr (>= 0.1.1), purrr (>= 0.2.4), readr (>= 1.1.1), readxl\n(>= 1.0.0), reprex (>= 0.1.1), rlang (>= 0.1.4), rstudioapi (>=\n0.7), rvest (>= 0.3.2), stringr (>= 1.2.0), tibble (>= 1.3.4),\ntidyr (>= 0.7.2), xml2 (>= 1.1.1)
# timeDate     NA
# tinytex      xfun (>= 0.5)
# tools        NA
# translations NA
# TTR          xts (>= 0.10-0), zoo, curl
# utf8         NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        stats, graphics, grDevices
# xfun         tools
# xml2         Rcpp
# xtable       stats, utils
# xts          methods
# yaml         NA
# zoo          utils, graphics, grDevices, lattice (>= 0.20-27)
#              LinkingTo
# askpass      NA
# assertthat   NA
# backports    NA
# base         NA
# base64enc    NA
# BH           NA
# boot         NA
# broom        NA
# callr        NA
# caret        NA
# cellranger   NA
# class        NA
# cli          NA
# clipr        NA
# cluster      NA
# codetools    NA
# colorspace   NA
# compiler     NA
# crayon       NA
# curl         NA
# data.table   NA
# datasets     NA
# DBI          NA
# dbplyr       NA
# dichromat    NA
# digest       NA
# dplyr        BH (>= 1.58.0-1), plogr (>= 0.1.10), Rcpp (>= 1.0.0)
# ellipsis     NA
# evaluate     NA
# fansi        NA
# ...          ...
# splines      NA
# SQUAREM      NA
# stats        NA
# stats4       NA
# stringi      NA
# stringr      NA
# survival     NA
# sys          NA
# tcltk        NA
# tibble       NA
# tidyr        Rcpp
# tidyselect   Rcpp (>= 0.12.0),
# tidyverse    NA
# timeDate     NA
# tinytex      NA
# tools        NA
# translations NA
# TTR          xts
# utf8         NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        NA
# xfun         NA
# xml2         Rcpp (>= 0.12.12)
# xtable       NA
# xts          zoo
# yaml         NA
# zoo          NA
#              Suggests
# askpass      testthat
# ...
# utils        methods, xml2, commonmark
# uuid         NA
# viridisLite  hexbin (>= 1.27.0), ggplot2 (>= 1.0.1), testthat, covr
# whisker      markdown
# withr        testthat, covr, lattice, DBI, RSQLite, methods, knitr,\nrmarkdown
# xfun         testit, parallel, rstudioapi, tinytex, mime, markdown, knitr,\nhtmltools, base64enc, remotes, rmarkdown
# xml2         testthat, curl, covr, knitr, rmarkdown, magrittr, httr
# xtable       knitr, plm, zoo, survival
# xts          timeSeries, timeDate, tseries, chron, fts, tis, RUnit
# yaml         RUnit
# zoo          coda, chron, DAAG, fts, ggplot2, mondate, scales,\nstrucchange, timeDate, timeSeries, tis, tseries, xts
#              Enhances License                                License_is_FOSS
# askpass      NA       MIT + file LICENSE                     NA
# assertthat   NA       GPL-3                                  NA
# backports    NA       GPL-2                                  NA
# base         NA       Part of R 3.6.1                        NA
# base64enc    png      GPL-2 | GPL-3                          NA
# BH           NA       BSL-1.0                                NA
# boot         NA       Unlimited                              NA
# broom        NA       MIT + file LICENSE                     NA
# callr        NA       MIT + file LICENSE                     NA
# caret        NA       GPL (>= 2)                             NA
# cellranger   NA       MIT + file LICENSE                     NA
# class        NA       GPL-2 | GPL-3                          NA
# cli          NA       MIT + file LICENSE                     NA
# clipr        NA       GPL-3                                  NA
# cluster      NA       GPL (>= 2)                             NA
# codetools    NA       GPL                                    NA
# colorspace   NA       BSD_3_clause + file LICENSE            NA
# compiler     NA       Part of R 3.6.1                        NA
# crayon       NA       MIT + file LICENSE                     NA
# curl         NA       MIT + file LICENSE                     NA
# data.table   NA       MPL-2.0 | file LICENSE                 NA
# datasets     NA       Part of R 3.6.1                        NA
# DBI          NA       LGPL (>= 2)                            NA
# dbplyr       NA       MIT + file LICENSE                     NA
# dichromat    NA       GPL-2                                  NA
# digest       NA       GPL (>= 2)                             NA
# dplyr        NA       MIT + file LICENSE                     NA
# ellipsis     NA       GPL-3                                  NA
# evaluate     NA       MIT + file LICENSE                     NA
# fansi        NA       GPL (>= 2)                             NA
# ...          ...      ...                                    ...
# splines      NA       Part of R 3.6.1                        NA
# SQUAREM      NA       GPL (>= 2)                             NA
# stats        NA       Part of R 3.6.1                        NA
# stats4       NA       Part of R 3.6.1                        NA
# stringi      NA       file LICENSE                           yes
# stringr      NA       GPL-2 | file LICENSE                   NA
# survival     NA       LGPL (>= 2)                            NA
# sys          NA       MIT + file LICENSE                     NA
# tcltk        NA       Part of R 3.6.1                        NA
# tibble       NA       MIT + file LICENSE                     NA
# tidyr        NA       MIT + file LICENSE                     NA
# tidyselect   NA       GPL-3                                  NA
# tidyverse    NA       GPL-3 | file LICENSE                   NA
# timeDate     NA       GPL (>= 2)                             NA
# tinytex      NA       MIT + file LICENSE                     NA
# tools        NA       Part of R 3.6.1                        NA
# translations NA       Part of R 3.6.1                        NA
# TTR          quantmod GPL-2                                  NA
# utf8         NA       Apache License (== 2.0) | file LICENSE NA
# utils        NA       Part of R 3.6.1                        NA
# uuid         NA       MIT + file LICENSE                     NA
# viridisLite  NA       MIT + file LICENSE                     NA
# whisker      NA       GPL-3                                  NA
# withr        NA       GPL (>= 2)                             NA
# xfun         NA       MIT + file LICENSE                     NA
# xml2         NA       GPL (>= 2)                             NA
# xtable       NA       GPL (>= 2)                             NA
# xts          NA       GPL (>= 2)                             NA
# yaml         NA       BSD_3_clause + file LICENSE            NA
# zoo          NA       GPL-2 | GPL-3                          NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# askpass      NA                    NA      NA     yes              3.6.0
# assertthat   NA                    NA      NA     no               3.6.0
# backports    NA                    NA      NA     yes              3.6.0
# base         NA                    NA      NA     NA               3.6.1
# base64enc    NA                    NA      NA     yes              3.6.0
# BH           NA                    NA      NA     no               3.6.0
# boot         NA                    NA      NA     no               3.6.0
# broom        NA                    NA      NA     no               3.6.0
# callr        NA                    NA      NA     no               3.6.0
# caret        NA                    NA      NA     yes              3.6.0
# cellranger   NA                    NA      NA     no               3.6.0
# class        NA                    NA      NA     yes              3.6.0
# cli          NA                    NA      NA     no               3.6.0
# clipr        NA                    NA      NA     no               3.6.0
# cluster      NA                    NA      NA     yes              3.6.0
# codetools    NA                    NA      NA     no               3.6.0
# colorspace   NA                    NA      NA     yes              3.6.0
# compiler     NA                    NA      NA     NA               3.6.1
# crayon       NA                    NA      NA     no               3.6.0
# curl         NA                    NA      NA     yes              3.6.0
# data.table   NA                    NA      NA     yes              3.6.0
# datasets     NA                    NA      NA     NA               3.6.1
# DBI          NA                    NA      NA     no               3.6.0
# dbplyr       NA                    NA      NA     no               3.6.0
# dichromat    NA                    NA      NA     NA               3.6.0
# digest       NA                    NA      NA     yes              3.6.0
# dplyr        NA                    NA      NA     yes              3.6.0
# ellipsis     NA                    NA      NA     yes              3.6.0
# evaluate     NA                    NA      NA     no               3.6.0
# fansi        NA                    NA      NA     yes              3.6.0
# ...          ...                   ...     ...    ...              ...
# splines      NA                    NA      NA     yes              3.6.1
# SQUAREM      NA                    NA      NA     no               3.6.0
# stats        NA                    NA      NA     yes              3.6.1
# stats4       NA                    NA      NA     NA               3.6.1
# stringi      NA                    NA      NA     yes              3.6.0
# stringr      NA                    NA      NA     no               3.6.0
# survival     NA                    NA      NA     yes              3.6.0
# sys          NA                    NA      NA     yes              3.6.0
# tcltk        NA                    NA      NA     yes              3.6.1
# tibble       NA                    NA      NA     yes              3.6.0
# tidyr        NA                    NA      NA     yes              3.6.0
# tidyselect   NA                    NA      NA     yes              3.6.0
# tidyverse    NA                    NA      NA     no               3.6.0
# timeDate     NA                    NA      NA     no               3.6.0
# tinytex      NA                    NA      NA     no               3.6.0
# tools        NA                    NA      NA     yes              3.6.1
# translations NA                    NA      NA     NA               3.6.1
# TTR          NA                    NA      NA     yes              3.6.0
# utf8         NA                    NA      NA     yes              3.6.0
# utils        NA                    NA      NA     yes              3.6.1
# uuid         NA                    NA      NA     yes              3.6.0
# viridisLite  NA                    NA      NA     no               3.6.0
# whisker      NA                    NA      NA     no               3.6.0
# withr        NA                    NA      NA     no               3.6.0
# xfun         NA                    NA      NA     no               3.6.0
# xml2         NA                    NA      NA     yes              3.6.0
# xtable       NA                    NA      NA     no               3.6.0
# xts          NA                    NA      NA     yes              3.6.0
# yaml         NA                    NA      NA     yes              3.6.0
# zoo          NA                    NA      NA     yes              3.6.0

# %%
# Carregando um pacote
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
# Verifica os pacotes carregados na memória
search()
# Out:
#  [1] ".GlobalEnv"        "package:ggplot2"   "jupyter:irkernel"
#  [4] "package:stats"     "package:graphics"  "package:grDevices"
#  [7] "package:utils"     "package:datasets"  "package:methods"
# [10] "Autoloads"         "package:base"

# %%
# Descarregando desalocando pacote da memória
detach("package:ggplot2")

# %%
# Verifica os pacotes carregados na memória
search()
# Out:
#  [1] ".GlobalEnv"        "jupyter:irkernel"  "package:stats"
#  [4] "package:graphics"  "package:grDevices" "package:utils"
#  [7] "package:datasets"  "package:methods"   "Autoloads"
# [10] "package:base"

# %% [markdown]
# ## Operadores aritméticos
#
# | Operador | Significado   | Exemplo                    |
# |:---|:---|:---|
# |     +    | Adição        | a = 3 + 2                  |
# |     -    | Subtração     | b = 7 - a                  |
# |     *    | Multiplicação | c = a * b                  |
# |     /    | Divisão       | d = 10 / 3                   |
# |    %/%    | Quociente     | e = 10 %/% 3                  |
# |     %%    | Resto         | f = 10 %% 3                   |
# |    **   | Exponenciação | g = 2 ** 3               |
# |    ^    | Exponenciação | g = 2 ^ 3                |
# |    **   | Radiciação    | h = 16 ** (1/2) |
# |    ^    | Radiciação    | h = 16 ^ (1/2)            |
#
# ## Precedência de Operadores
#
# 1. Parênteses
# 2. Potenciação
# 3. Multiplicação e divisão
# 4. Soma e subtração

# %%
# Definindo as variáveis a e b
a = 10L
b = 3L
#Adição (+)
adic = a + b
adic # ou print(adic)
# Out:
# [1] 13

# %%
# Subtração (-)
subt = a - b
subt
# Out:
# [1] 7

# %%
# Multiplicação
mult = a * b
mult
# Out:
# [1] 30

# %%
# Divisão real
divi = a / b
divi
# Out:
# [1] 3.333333

# %%
# Divisão inteira (quociente)
quoc = a %/% b
quoc
# Out:
# [1] 3

# %%
# Divisão inteira (resto)
resto = a %% b
resto
# Out:
# [1] 1

# %%
# Potenciação
potencia1 = 2 ** 3
potencia2 = 3 ^ 2
potencia3 = 9 ** (1/2)
print(c(potencia1, potencia2, potencia3))
# Out:
# [1] 8 9 3

# %% [markdown]
# ## Exercício de fixação
#
# Converter as equações em expressões aritméticas válidas no R.
#
# Equação 1     $\Rightarrow 2+3 \times 4 \div 5 - 6 $

# %%
2 + 3 * (4 / 5) - 6
# Out:
# [1] -1.6

# %% [markdown]
# Agora a mesma equação acima, mas alterando a precedência para que as operações de soma e subtração sejam executadas antes das outras. _Dica: use parênteses._

# %%
(2 + 3) * 4 / (5 - 6)
# Out:
# [1] -20

# %% [markdown]
# Equação 2 $\Rightarrow \sqrt{\frac{(2-3)^{2}}{4}}$

# %%
((2-3)**2/4)**(1/2)
# Out:
# [1] 0.5

# %%
(((2-3)**2)/4)**(1/2)
# Out:
# [1] 0.5

# %% [markdown]
# ## Tipos de Dados em R
#
# Segundo o [R Language Definition](https://cran.r-project.org/doc/manuals/r-release/R-lang.html), R contém seis tipos básicos de dados. São eles:
#
# * integer (ex: 2L, 5L | varia entre -2.147.483.647 a +2.147.483.647)
# * double (ex: 3.14159, 0.0001, 9999999999999999 | varia entre 2.22507e-308 e 1.79769e+308)
# * complex (ex: 3+2i, 7i)
# * character (ex: "R", "Jupyter")
# * logical (TRUE, FALSE)
# * raw (ex: 52, 5a)

# %%
a = 
a
# Out:
# [1] 1.79769e+308

# %%
typeof(a)
# Out:
# [1] "double"

# %%
b = 2147483647L # ou b = as.integer(2147483647)
b
# Out:
# [1] 2147483647

# %%
typeof(b)
# Out:
# [1] "integer"

# %%
c = 3 + 2i
c
# Out:
# [1] 3+2i

# %%
typeof(c)
# Out:
# [1] "complex"

# %%
d = "texto"
d
# Out:
# [1] "texto"

# %%
typeof(d)
# Out:
# [1] "character"

# %%
e = TRUE # e = T
e
# Out:
# [1] TRUE

# %%
typeof(e)
# Out:
# [1] "logical"

# %%
f <- charToRaw("A")
f
# Out:
# [1] 41

# %%
typeof(f)
# Out:
# [1] "raw"

# %% [markdown]
# ## Verificando tipos de dados e variáveis em R
#
# ### typeof()
#
# O R fornece o método **typeof()** que retorna o tipo de dados e variáveis. Seu uso é muito simples, basta chamar a função passando por parâmetro um objeto, variável ou um valor entre parênteses.

# %%
typeof(a)
# Out:
# [1] "double"

# %%
typeof(3)
# Out:
# [1] "double"

# %%
typeof(3L)
# Out:
# [1] "integer"

# %%
typeof("R")
# Out:
# [1] "character"

# %%
typeof(TRUE)
# Out:
# [1] "logical"

# %%
typeof(3+2i)
# Out:
# [1] "complex"

# %%
charToRaw("Hello")
# Out:
# [1] 48 65 6c 6c 6f

# %%
ctr = charToRaw("Hello")
typeof(ctr)
# Out:
# [1] "raw"

# %%
vetorInt = c(3L, 9L, 2L, 6L)
typeof(vetorInt)
# Out:
# [1] "integer"

# %%
vetorDouble = c(3, 9, 2, 6)
typeof(vetorDouble)
# Out:
# [1] "double"

# %%
vetorComplex = c(3+2i, 9-5i, 2i, 6)
typeof(vetorComplex)
# Out:
# [1] "complex"

# %%
vetorChar = c("R", "Python", "Hadoop", "GGPlot2")
typeof(vetorChar)
# Out:
# [1] "character"

# %%
vetorLog = c(TRUE, 5 < 10, FALSE, 3 > 4)
typeof(vetorLog)
# Out:
# [1] "logical"

# %%
vetorRaw = c(charToRaw("R"), charToRaw("Python"), charToRaw("Hadoop"), charToRaw("GGPlot2"))
typeof(vetorRaw)
# Out:
# [1] "raw"

# %%
x = charToRaw("Z")
x
# Out:
# [1] 5a

# %%
rawToChar(x)
# Out:
# [1] "Z"

# %% [markdown]
# ## Variáveis e o comando de atribuição
#
# ### Conceito de variável
# O que é uma [variável](https://pt.wikipedia.org/wiki/Variável_\(programação\) "Conceito de variável no Wikipedia")? De forma bem simples e objetiva, uma **variável** é um espaço na memória (*memória RAM*) do seu computador, utilizada por um programa para armazenar dados.
#
#
# ### Identificadores
#
# Uma variável precisa necessariamente de um nome, o qual chamamos de **identificador**. Em R, um identificador é formado apenas por letras (_de A a Z, maiúsculas ou minúsculas, com ou sem acentuação_), dígitos (_0 a 9_), o _underscore_ ( \_ ) e o _ponto_ ( . ). Um identificador deve começar **obrigatoriamente** com uma letra ou ponto seguido por um qualquer caractere que não seja dígito. Também não pode conter espaços e caracteres especiais (@, !, \*, -, &, ˜, etc).
#
# #### Identificadores válidos e inválidos
# Portanto podemos considerar os seguintes identificadores como nomes válidos para variáveis:
#
# * nome
# * Salário
# * NUMERO10\_
# * i23ER21
# * \..\_data\_de\_nascimento\_
#
# Já os identificadores abaixo não são nomes válidos para variáveis:
# * nome do aluno (*identificadores não podem conter espaços*)
# * Sal\@rio (*contém um caractere especial @*)
# * 10NUMERO (*começa com dígito*)
# * \_23ER21 (*começa com underscore \_*)
# * data-de-nascimento (*possui um caractere especial -*)
#
# #### Identificadores significativos e não significativos
#
# Além de serem válidos, como nos exemplos acima, os **identificadores** precisam ter nomes significativos. Ou seja, ao ver um identificador, o programador deve conseguir perceber que dado está armazenado na variável.
#
# Os identificadores abaixo, embora sejam válidos, não tem nomes significativos:
#
# * i23ER1
# * .a123
# * BATMAN
# * T
#
# Embora todos os identificadores acima sejam válidos, não são significativos. Que informação será armazenada nas variáveis *i23ER21*, *.a123*, *BATMAN* ou *T*? É difícil descobrir.
#
# Os identificadores abaixo são válidos e tem nomes significativos:
#
# * salario
# * idade
# * nome
# * nota
# * complementoenderecoparacorrespondencia
#
# Uma observação importante: para que um nome seja significativo, ele não precisa ser tão longo quanto _complementoenderecoparacorrespondencia_. Por exemplo, o que a variável `dtnasc` armazena? Se você pensou em uma data de nascimento, você acertou. Não precisamos de identificadores longos como *data\_de\_nascimento* para criar identificadores significativos. O ideal é utilizar identificadores mais curtos e fáceis de memorizar e utilizar como _dtnasc_.
#
# Por fim, uma última informação. R faz diferenciação entre letras maiúsculas e minúsculas em identificadores. Portanto, os identificadores _nota, Nota e NOTA_ representam três variáveis diferentes.
#
# ### Criando variáveis
#
# Variáveis em R não são **declaradas** como em outras linguagens *(ex: Pascal, C, C++, Java, C#, etc...)* mas **criadas** a partir da atribuição de um valor, uma variável, uma expressão ou um objeto. O comando de atribuição, representado pelos símbolos (`=`,  `<-` ou `->`), é o responsável por atribuir (ou armazenar) um valor em uma variável. Também é possível atribuir um valor a uma variável através da função _assign()_.
#
# Vejamos alguns exemplos:

# %%
idade = 47L # ou idade = as.integer(47)
idade
# Out:
# [1] 47

# %%
qtdeFilhos <- 2
qtdeFilhos
# Out:
# [1] 2

# %%
assign("peso",70.9)
peso
# Out:
# [1] 70.9

# %%
'José Maria da Silva' -> nome
nome
# Out:
# [1] "José Maria da Silva"

# %%
altura = 1.72
altura
# Out:
# [1] 1.72

# %%
casado = TRUE
casado
# Out:
# [1] TRUE

# %% [markdown]
# ## Testando tipo de dados e de variáveis

# %%
is.integer(1)
# Out:
# [1] FALSE

# %%
x = as.integer(5)

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
is.integer(1L)
# Out:
# [1] TRUE

# %%
is.character("A")
# Out:
# [1] TRUE

# %%
is.numeric(15)
# Out:
# [1] TRUE

# %%
is.double(15)
# Out:
# [1] TRUE

# %%
is.raw(15)
# Out:
# [1] FALSE

# %%
is.logical(TRUE)
# Out:
# [1] TRUE

# %%
is.complex(2i)
# Out:
# [1] TRUE

# %% [markdown]
# ## Imprimindo valores e variáveis
#
# O R fornece o método print para impressão de valores e variáveis.

# %%
nome = "Maria"
print(nome)
# Out:
# [1] "Maria"

# %%
print("nome")
# Out:
# [1] "nome"

# %%
print("nome",nome)
# Out:
# Warning message in print.default("nome", nome):
# "NAs introduzidos por coerção"
# Error in print.default("nome", nome): argumento 'digits' inválido
# Traceback:
#
# 1. print("nome", nome)
# 2. print.default("nome", nome)

# %%
# imprime sem espaços, separador não tem.
print(paste0("nome ",nome))
# Out:
# [1] "nome Maria"

# %%
# imprime com espaços, separador padrão é Espaços, mas pode trocar.
paste("Meu","nome","é","Maria")
# Out:
# [1] "Meu nome é Maria"

# %%
print(paste("Meu","nome","é","Maria"))
# Out:
# [1] "Meu nome é Maria"

# %%
paste0("Meu","nome","é","Maria")
# Out:
# [1] "MeunomeéMaria"

# %%
print(paste0("Meu","nome","é","Maria"))
# Out:
# [1] "MeunomeéMaria"

# %%
cat("Meu","nome","é","Maria")
# Out:
# Meu nome é Maria

# %%
paste("Meu","nome","é","Maria", sep="&")
# Out:
# [1] "Meu&nome&é&Maria"

# %% [markdown]
# ## Dica print(), cat(), paste() e paste0()
#
# * Para imprimir mensagens mais elaboradas, use apenas o cat() ou o print() em conjunto com paste() ou paste0().
# * Lembre-se que a diferença entre paste() e paste0() é que, por *default*, o separador em paste é " " e em paste0 é ""

# %%
idade = as.integer(readline(prompt="Digite sua idade: "))
# Out:
# Digite sua idade: 37

# %%
nome = readline(prompt="Digite seu nome: ")
# Out:
# Digite seu nome: Rafael Sucra

# %%
cat(nome,"tem",idade,"anos de idade.")
# Out:
# Rafael Sucra tem 37 anos de idade.

# %%
print(paste(nome,"tem",idade,"anos de idade."))
# Out:
# [1] "Rafael Sucra tem 37 anos de idade."

# %% [markdown]
# # Transformando equações matemáticas em expressões aritméticas
#
# ### Cálculo da área e perímetro do retângulo
#
# $area = base \times altura$
#
# $ perímetro = 2 \times (base + altura)$

# %%
base = 7
altura = 8
area = base * altura
perimetro = 2 * (base + altura)
print(area)
print(perimetro)
# Out:
# [1] 56
# [1] 30

# %%
base = as.double(readline(prompt="Digite a base: "))
altura = as.double(readline(prompt="Digite a altura: "))
typeof(base)
typeof(altura)
area = base * altura
perimetro = 2 * (base + altura)
print(area)
print(perimetro)
# Out:
# Digite a base: 6
# Digite a altura: 7
# [1] "double"
# [1] 42
# [1] 26

# %% [markdown]
# ### Cálculo da área e comprimento da circunferência
#
# $ area = \pi \times raio^{2} $
#
# $ comprimento = 2 \times \pi * raio $

# %%
raio = 2
area = pi * raio ** 2
comprimento = 2 * pi * raio
cat("Para o raio",raio,", a área =",area,"e o comprimento =", comprimento)

# %%
raio = as.double(readline(prompt="Digite o raio: "))
typeof(raio)
area = pi * raio ** 2
comprimento = 2 * pi * raio
cat("Para o raio",raio,", a área =",area,"e o comprimento =", comprimento)
# Out:
# Digite o raio: 8
# [1] "double"
# Para o raio 8 , a área = 201.0619 e o comprimento = 50.26548

# %%
# Calculando a área e comprimento de uma circunferência cujo raio será informado pelo usuário
raio = as.numeric(readline(prompt="Digite o valor do raio: "))
area = pi * raio ** 2
comprimento = 2 * pi * raio
cat("Para o raio",raio,", a área =",area,"e o comprimento =", comprimento)
# Out:
# Digite o valor do raio: 8
# Para o raio 8 , a área = 201.0619 e o comprimento = 50.26548

# %% [markdown]
# ### Cálculo da distância euclidiana entre 2 pontos no plano cartesiano
#
# $ distância = \sqrt{(x_{1}-x_{2})^{2} + (y_{1}-y_{2})^{2}} $

# %%
# Calculando a distância entre os pontos (3,4) e (5,6)
x1 = 3
y1 = 4
x2 = 5
y2 = 6
dist = ((x1-x2)**2 + (y1-y2)**2)**(1/2)
cat("A distância entre os pontos(",x1,",",y1,") e (",x2,",",y2,") =",dist)
# Out:
# A distância entre os pontos( 3 , 4 ) e ( 5 , 6 ) = 2.828427

# %%
# Calculando a distância entre os pontos digitados pelo usuário
x1 = as.numeric(readline(prompt="Digite o valor de x1: "))
y1 = as.numeric(readline(prompt="Digite o valor de y1: "))
x2 = as.numeric(readline(prompt="Digite o valor de x2: "))
y2 = as.numeric(readline(prompt="Digite o valor de y2: "))
dist = ((x1-x2)**2 + (y1-y2)**2)**(1/2)
cat("A distância entre os pontos(",x1,",",y1,") e (",x2,",",y2,") =",dist)
# Out:
# Digite o valor de x1: 5
# Digite o valor de y1: 6
# Digite o valor de x2: 7
# Digite o valor de y2: 8
# A distância entre os pontos( 5 , 6 ) e ( 7 , 8 ) = 2.828427

# %% [markdown]
# ### Cálculo do delta e das raízes de uma equação do segundo grau
#
# $ \Delta = b^{2} - 4ac $
#
# $ x = \frac{-b \pm \sqrt{\Delta}}{2a} $

# %%
# Calculando o Delta e raízes x1 e x2 para a equação y = x^2 - 5x + 6
a = 1
b = -5
c = 6
delta = b**2 - 4*a*c
x1 = (-b+delta**(1/2))/(2*a)
x2 = (-b-delta**(1/2))/(2*a)
cat("Delta =",delta,", x1 =",x1,"e x2 =", x2)
# Out:
# Delta = 1 , x1 = 3 e x2 = 2

# %%
# Calculando o Delta e raízes x1 e x2 para a equação cujos coeficientes serão informados pelo usuário
a = as.numeric(readline("Digite o valor do coeficiente a: "))
b = as.numeric(readline("Digite o valor do coeficiente b: "))
c = as.numeric(readline("Digite o valor do coeficiente c: "))
delta = b**2 - 4*a*c
x1 = (-b+delta**(1/2))/(2*a)
x2 = (-b-delta**(1/2))/(2*a)
cat("Delta =",delta,", x1 =",x1,"e x2 =", x2)
# Out:
# Digite o valor do coeficiente a: 1
# Digite o valor do coeficiente b: -10
# Digite o valor do coeficiente c: 6
# Delta = 76 , x1 = 9.358899 e x2 = 0.6411011

# %% [markdown]
# ### Cálculo da área do setor circular (fatia de um círculo)
#
# $ S = \frac{\alpha \pi r^{2}}{360} $

# %%
# Para um círculo de raio 15, calcular a área de uma fatia com angulo = 45 graus (um pizza)
# Isso equivale a calcular a área de uma das 8 fatias de uma pizza com 30 cm de diâmetro
a = 45
r = 15
s = (a * pi * r ** 2)/360
cat("Num círculo de raio",r,"cm, o setor circular de ângulo",a,"terá área =",s,"cm^2.")

# %%
a = as.numeric(readline(prompt="Digite a Area: "))
r = as.numeric(readline(prompt="Digite a Raio: "))
s = (a * pi * r ** 2)/360
cat("Num círculo de raio",r,"cm, o setor circular de ângulo",a,"terá área =",s,"cm^2.")
# Out:
# Digite a Area: 5
# Digite a Raio: 8
# Num círculo de raio 8 cm, o setor circular de ângulo 5 terá área = 2.792527 cm^2.

# %% [markdown]
# ## Operadores relacionais (operadores de comparação)
#
# | Operador | Significado   | Exemplo                    |
# |:---|:---|:---|
# | == | Igualdade | a == b |
# | != | DesiIgualdade | a != b |
# | > | Maior que | a > b |
# | < | Menor que | a < b |
# | >= | Maior ou igual | a >= b |
# | <= | Menor ou igual | a <= b |

# %%
a = 5
b = 3
a == b
# Out:
# [1] FALSE

# %%
a = as.numeric(readline(prompt="Digite primeiro numero: "))
b = as.numeric(readline(prompt="Digite segundo numero: "))
c <- a == b
print(paste(a,"é igual a",b,c))
# Out:
# Digite primeiro numero: 4
# Digite segundo numero: 7
# [1] "4 é igual a 7 FALSE"

# %%
a != b
# Out:
# [1] TRUE

# %%
a > b
# Out:
# [1] FALSE

# %%
a < b
# Out:
# [1] TRUE

# %%
a >= b
# Out:
# [1] FALSE

# %%
b <= a
# Out:
# [1] FALSE

# %% [markdown]
# ## Operadores lógicos (conectivos lógicos)
#
# | Operador | Significado   | Exemplo                    |
# |:---|:---|:---|
# | & ou && | **E** lógico | a == b & b == c |
# | \| ou \|\| | **OU** lógico | a == b \| b == c |
# | xor | **OU** exclusivo (XOR) | a == b xor b == c |
# | ! | Negação (inverte o resultado lógico) | !(a == b & b == c) |
#
# ### Tabela verdade (AND)
#
# | a | b | a & b |
# |:--:|:--:|:--:|
# | True  | True  | **True** |
# | True  | False | False |
# | False | True  | False |
# | False | False | False |
#
# | a | b | c | a & b & c |
# |:--:|:--:|:--:|:--:|
# | True  | True  | True  | **True** |
# | True  | True  | False | False |
# | True  | False | True  | False |
# | True  | False | False | False |
# | False | True  | True  | False |
# | False | True  | False | False |
# | False | False | True  | False |
# | False | False | False | False |
#
# ### Tabela verdade (OR)
#
# | a | b | a \| b |
# |:--:|:--:|:--:|
# | True  | True  | **True** |
# | True  | False | **True** |
# | False | True  | **True** |
# | False | False | False |
#
# ### Tabela verdade (XOR)
#
# | a | b | a xor b |
# |:--:|:--:|:--:|
# | True  | True  | False |
# | True  | False | **True** |
# | False | True  | **True** |
# | False | False | False |
#
# ### Tabela verdade (NOT)
# | a | !(a) |
# |:--:|:--:|
# | True  | False |
# | False | **True** |

# %%
# TABELA DO AND (com 2 booleanos)
print(paste(" x     | y     | x and y "))
print(paste("-------------------------"))
print(paste(" TRUE  | TRUE  |", TRUE && TRUE ))
print(paste(" TRUE  | FALSE |", TRUE & FALSE ))
print(paste(" FALSE | TRUE  |", FALSE & TRUE))
print(paste(" False | FALSE |", FALSE & FALSE))
# Out:
# [1] " x     | y     | x and y "
# [1] "-------------------------"
# [1] " TRUE  | TRUE  | TRUE"
# [1] " TRUE  | FALSE | FALSE"
# [1] " FALSE | TRUE  | FALSE"
# [1] " False | FALSE | FALSE"

# %%
# TABELA DO AND (com 3 booleanos)
print(paste(" x     | y     | z     |  x and y and z "))
print(paste("----------------------------------------"))
print(paste(" TRUE  | TRUE  | TRUE  |",TRUE & TRUE & TRUE))
print(paste(" TRUE  | TRUE  | FALSE |",TRUE & TRUE & FALSE))
print(paste(" TRUE  | FALSE | TRUE  |",TRUE & FALSE & TRUE))
print(paste(" TRUE  | FALSE | FALSE |",TRUE & FALSE & FALSE))
print(paste(" FALSE | TRUE  | TRUE  |",FALSE & TRUE & TRUE))
print(paste(" FALSE | TRUE  | FALSE |",FALSE & TRUE & FALSE))
print(paste(" FALSE | FALSE | TRUE  |",FALSE & FALSE & TRUE))
print(paste(" FALSE | FALSE | FALSE |",FALSE & FALSE & FALSE))
# Out:
# [1] " x     | y     | z     |  x and y and z "
# [1] "----------------------------------------"
# [1] " TRUE  | TRUE  | TRUE  | TRUE"
# [1] " TRUE  | TRUE  | FALSE | FALSE"
# [1] " TRUE  | FALSE | TRUE  | FALSE"
# [1] " TRUE  | FALSE | FALSE | FALSE"
# [1] " FALSE | TRUE  | TRUE  | FALSE"
# [1] " FALSE | TRUE  | FALSE | FALSE"
# [1] " FALSE | FALSE | TRUE  | FALSE"
# [1] " FALSE | FALSE | FALSE | FALSE"

# %%
# TABELA DO OR (com 2 booleanos)
print(paste(" x     | y     | x or y "))
print(paste("-------------------------"))
print(paste(" TRUE  | TRUE  |", TRUE | TRUE ))
print(paste(" TRUE  | FALSE |", TRUE | FALSE ))
print(paste(" FALSE | TRUE  |", FALSE | TRUE))
print(paste(" False | FALSE |", FALSE | FALSE))
# Out:
# [1] " x     | y     | x or y "
# [1] "-------------------------"
# [1] " TRUE  | TRUE  | TRUE"
# [1] " TRUE  | FALSE | TRUE"
# [1] " FALSE | TRUE  | TRUE"
# [1] " False | FALSE | FALSE"

# %%
# TABELA DO XOR (com 2 booleanos)
print(paste(" x     | y     | x xor y "))
print(paste("-------------------------"))
print(paste(" TRUE  | TRUE  |", xor(TRUE, TRUE)))
print(paste(" TRUE  | FALSE |", xor(TRUE, FALSE)))
print(paste(" FALSE | TRUE  |", xor(FALSE, TRUE)))
print(paste(" False | FALSE |", xor(FALSE, FALSE)))
# Out:
# [1] " x     | y     | x xor y "
# [1] "-------------------------"
# [1] " TRUE  | TRUE  | FALSE"
# [1] " TRUE  | FALSE | TRUE"
# [1] " FALSE | TRUE  | TRUE"
# [1] " False | FALSE | FALSE"

# %%
# TABELA DO NOT
print(paste(" x     | not(x) "))
print(paste("----------------"))
print(paste(" True  |",!(TRUE)))
print(paste(" False |",!(FALSE)))
# Out:
# [1] " x     | not(x) "
# [1] "----------------"
# [1] " True  | FALSE"
# [1] " False | TRUE"

# %% [markdown]
# ## Gerenciando objetos na memória

# %%
# Lista todos os objetos alocados na memória
ls() # Também pode ser usada a função objects()
# Out:
#  [1] "a"            "adic"         "altura"       "area"         "b"
#  [6] "base"         "c"            "casado"       "comprimento"  "ctr"
# [11] "d"            "delta"        "dist"         "divi"         "e"
# [16] "f"            "idade"        "mult"         "nome"         "perimetro"
# [21] "peso"         "potencia1"    "potencia2"    "potencia3"    "qtdeFilhos"
# [26] "quoc"         "r"            "raio"         "resto"        "s"
# [31] "subt"         "vetorChar"    "vetorComplex" "vetorDouble"  "vetorInt"
# [36] "vetorLog"     "vetorRaw"     "x"            "x1"           "x2"
# [41] "y1"           "y2"

# %%
# Lista todos os objetos alocados na memória
objects() # Também pode ser usada a função ls()
# Out:
#  [1] "a"            "adic"         "altura"       "area"         "b"
#  [6] "base"         "c"            "casado"       "comprimento"  "ctr"
# [11] "d"            "delta"        "dist"         "divi"         "e"
# [16] "f"            "idade"        "mult"         "nome"         "perimetro"
# [21] "peso"         "potencia1"    "potencia2"    "potencia3"    "qtdeFilhos"
# [26] "quoc"         "r"            "raio"         "resto"        "s"
# [31] "subt"         "vetorChar"    "vetorComplex" "vetorDouble"  "vetorInt"
# [36] "vetorLog"     "vetorRaw"     "x"            "x1"           "x2"
# [41] "y1"           "y2"

# %%
# Removendo um objeto específico
remove(altura) # ou rm(altura)

# %%
ls()
# Out:
#  [1] "a"            "adic"         "area"         "b"            "base"
#  [6] "c"            "casado"       "comprimento"  "ctr"          "d"
# [11] "delta"        "dist"         "divi"         "e"            "f"
# [16] "idade"        "mult"         "nome"         "perimetro"    "peso"
# [21] "potencia1"    "potencia2"    "potencia3"    "qtdeFilhos"   "quoc"
# [26] "r"            "raio"         "resto"        "s"            "subt"
# [31] "vetorChar"    "vetorComplex" "vetorDouble"  "vetorInt"     "vetorLog"
# [36] "vetorRaw"     "x"            "x1"           "x2"           "y1"
# [41] "y2"

# %%
# Removendo todos os objetos
remove(list = ls()) # ou rm(list = ls())
ls()
# Out:
# character(0)

# %%
# Removendo objetos específicos
a = 5
b = 6
c = 7
rm(list = c("a", "c"))
ls()
# Out:
# [1] "b"
